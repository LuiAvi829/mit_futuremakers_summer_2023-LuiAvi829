# %% [markdown]
# <a href="https://colab.research.google.com/github/MySureStart/mit_futuremakers_summer_2023-LuiAvi829/blob/main/Module_12_Regularization/Regularization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image_2021-10-30_133041.png](data:image/png;base64,...)

# %% [markdown]
# #Objective
# * To acquaint you with the problem of overfit models and to mitigate it with regularization

# %%
# Basic packages
import pandas as pd
import numpy as np
import re
import collections
import matplotlib.pyplot as plt
from pathlib import Path

# Packages for data preparation
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords
from keras.preprocessing.text import Tokenizer
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import LabelEncoder

import nltk
nltk.download('stopwords')

# Packages for modeling
import tensorflow as tf
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import regularizers

NB_WORDS = 10000  # Parameter indicating the number of words we'll put in the dictionary
NB_START_EPOCHS = 20  # Number of epochs we usually start to train with
BATCH_SIZE = 512  # Size of the batches used in the mini-batch gradient descent
MAX_LEN = 20  # Maximum number of words in a sequence

root = Path('../content/')
input_path = root / 'input/'
ouput_path = root / 'output/'
source_path = root / 'source/'

def deep_model(model, X_train, y_train, X_valid, y_valid):
    model.compile(optimizer='rmsprop'
                  , loss='categorical_crossentropy'
                  , metrics=['accuracy'])

    history = model.fit(X_train
                       , y_train
                       , epochs=NB_START_EPOCHS
                       , batch_size=BATCH_SIZE
                       , validation_data=(X_valid, y_valid)
                       , verbose=1)
    return history

def eval_metric(model, history, metric_name):
    metric = history.history[metric_name]
    val_metric = history.history['val_' + metric_name]

    e = range(1, NB_START_EPOCHS + 1)

    plt.plot(e, metric, 'bo', label='Train ' + metric_name)
    plt.plot(e, val_metric, 'b', label='Validation ' + metric_name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for ' + model.name)
    plt.legend()
    plt.show()

def remove_stopwords(input_text):
    stopwords_list = stopwords.words('english')
    # Some words which might indicate a certain sentiment are kept via a whitelist
    whitelist = ["n't", "not", "no"]
    words = input_text.split()
    clean_words = [word for word in words if (word not in stopwords_list or word in whitelist) and len(word) > 1]
    return " ".join(clean_words)

def remove_mentions(input_text):
    return re.sub(r'@\w+', '', input_text)

def test_model(model, X_train, y_train, X_test, y_test, epoch_stop):
    model.fit(X_train
              , y_train
              , epochs=epoch_stop
              , batch_size=BATCH_SIZE
              , verbose=1)
    results = model.evaluate(X_test, y_test)
    print()
    print('Test accuracy: {0:.2f}%'.format(results[1]*100))
    return results

def compare_models_by_metric(model_1, model_2, model_hist_1, model_hist_2, metric):
    metric_model_1 = model_hist_1.history[metric]
    metric_model_2 = model_hist_2.history[metric]

    e = range(1, NB_START_EPOCHS + 1)

    metrics_dict = {
        'acc' : 'Training Accuracy',
        'loss' : 'Training Loss',
        'val_acc' : 'Validation accuracy',
        'val_loss' : 'Validation loss'
    }

    metric_label = metrics_dict[metric]

    plt.plot(e, metric_model_1, 'bo', label=model_1.name)
    plt.plot(e, metric_model_2, 'b', label=model_2.name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_label)
    plt.title('Comparing ' + metric_label + ' between models')
    plt.legend()
    plt.show()

def optimal_epoch(model_hist):
    min_epoch = np.argmin(model_hist.history['val_loss']) + 1
    print("Minimum validation loss reached in epoch {}".format(min_epoch))
    return min_epoch

! gdown --id 1QFupRVBpstzf_D6NiFvYQIO-MPuiwG9u
! mkdir input/
! mv Tweets.csv input/

df = pd.read_csv(input_path / 'Tweets.csv')
df = df.reindex(np.random.permutation(df.index))
df = df[['text', 'airline_sentiment']]
df.text = df.text.apply(remove_stopwords).apply(remove_mentions)

X_train, X_test, y_train, y_test = train_test_split(df.text, df.airline_sentiment, test_size=0.1, random_state=37)

tk = Tokenizer(num_words=NB_WORDS,
               filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~\t\n',
               lower=True,
               char_level=False,
               split=' ')
tk.fit_on_texts(X_train)

X_train_oh = tk.texts_to_matrix(X_train, mode='binary')
X_test_oh = tk.texts_to_matrix(X_test, mode='binary')

le = LabelEncoder()
y_train_le = le.fit_transform(y_train)
y_test_le = le.transform(y_test)
y_train_oh = to_categorical(y_train_le)
y_test_oh = to_categorical(y_test_le)

X_train_rest, X_valid, y_train_rest, y_valid = train_test_split(X_train_oh, y_train_oh, test_size=0.1, random_state=37)

base_model = models.Sequential()
base_model.add(layers.Dense(64, activation='relu', input_shape=(NB_WORDS,)))
base_model.add(layers.Dense(64, activation='relu'))
base_model.add(layers.Dense(3, activation='softmax'))
base_history = deep_model(base_model, X_train_rest, y_train_rest, X_valid, y_valid)
base_min = optimal_epoch(base_history)

reduced_model = models.Sequential()
reduced_model.add(layers.Dense(16, activation='relu', input_shape=(NB_WORDS,)))
reduced_model.add(layers.Dense(3, activation='softmax'))
reduced_history = deep_model(reduced_model, X_train_rest, y_train_rest, X_valid, y_valid)
reduced_min = optimal_epoch(reduced_history)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1QFupRVBpstzf_D6NiFvYQIO-MPuiwG9u
# To: /content/Tweets.csv
# 100% 3.42M/3.42M [00:00<00:00, 95.8MB/s]
# Epoch 1/20
# 24/24 [==============================] - 6s 146ms/step - loss: 0.8706 - accuracy: 0.6157 - val_loss: 0.6876 - val_accuracy: 0.6950
# Epoch 2/20
# 24/24 [==============================] - 2s 82ms/step - loss: 0.6325 - accuracy: 0.7356 - val_loss: 0.5479 - val_accuracy: 0.8012
# Epoch 3/20
# 24/24 [==============================] - 2s 95ms/step - loss: 0.4862 - accuracy: 0.8253 - val_loss: 0.4870 - val_accuracy: 0.8126
# Epoch 4/20
# 24/24 [==============================] - 1s 62ms/step - loss: 0.3965 - accuracy: 0.8602 - val_loss: 0.4729 - val_accuracy: 0.8156
# Epoch 5/20
# 24/24 [==============================] - 1s 62ms/step - loss: 0.3360 - accuracy: 0.8818 - val_loss: 0.4723 - val_accuracy: 0.8118
# Epoch 6/20
# 24/24 [==============================] - 2s 63ms/step - loss: 0.2869 - accuracy: 0.8999 - val_loss: 0.5315 - val_accuracy: 0.7807
# Epoch 7/20
# 24/24 [==============================] - 2s 66ms/step - loss: 0.2489 - accuracy: 0.9156 - val_loss: 0.5277 - val_accuracy: 0.7929
# Epoch 8/20
# 24/24 [==============================] - 1s 60ms/step - loss: 0.2174 - accuracy: 0.9274 - val_loss: 0.5257 - val_accuracy: 0.8050
# Epoch 9/20
# 24/24 [==============================] - 1s 62ms/step - loss: 0.1888 - accuracy: 0.9369 - val_loss: 0.5602 - val_accuracy: 0.8012
# Epoch 10/20
# 24/24 [==============================] - 2s 84ms/step - loss: 0.1654 - accuracy: 0.9451 - val_loss: 0.5891 - val_accuracy: 0.7959
# Epoch 11/20
# 24/24 [==============================] - 2s 93ms/step - loss: 0.1450 - accuracy: 0.9533 - val_loss: 0.6152 - val_accuracy: 0.7951
# Epoch 12/20
# 24/24 [==============================] - 1s 62ms/step - loss: 0.1275 - accuracy: 0.9588 - val_loss: 0.6541 - val_accuracy: 0.7853
# Epoch 13/20
# 24/24 [==============================] - 1s 60ms/step - loss: 0.1122 - accuracy: 0.9654 - val_loss: 0.6902 - val_accuracy: 0.7800
# Epoch 14/20
# 24/24 [==============================] - 1s 62ms/step - loss: 0.0992 - accuracy: 0.9687 - val_loss: 0.7298 - val_accuracy: 0.7800
# Epoch 15/20
# 24/24 [==============================] - 2s 67ms/step - loss: 0.0884 - accuracy: 0.9714 - val_loss: 0.7611 - val_accuracy: 0.7777
# Epoch 16/20
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0784 - accuracy: 0.9750 - val_loss: 0.7990 - val_accuracy: 0.7693
# Epoch 17/20
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0708 - accuracy: 0.9767 - val_loss: 0.8326 - val_accuracy: 0.7792
# Epoch 18/20
# 24/24 [==============================] - 2s 82ms/step - loss: 0.0623 - accuracy: 0.9804 - val_loss: 0.8768 - val_accuracy: 0.7747
# Epoch 19/20
# 24/24 [==============================] - 2s 92ms/step - loss: 0.0571 - accuracy: 0.9824 - val_loss: 0.8997 - val_accuracy: 0.7724
# Epoch 20/20
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0510 - accuracy: 0.9835 - val_loss: 0.9420 - val_accuracy: 0.7754
# Minimum validation loss reached in epoch 5
# Epoch 1/20
# 24/24 [==============================] - 2s 50ms/step - loss: 1.0178 - accuracy: 0.6130 - val_loss: 0.9267 - val_accuracy: 0.6737
# Epoch 2/20
# 24/24 [==============================] - 1s 45ms/step - loss: 0.8786 - accuracy: 0.6626 - val_loss: 0.8035 - val_accuracy: 0.7018
# Epoch 3/20
# 24/24 [==============================] - 1s 55ms/step - loss: 0.7702 - accuracy: 0.6886 - val_loss: 0.7142 - val_accuracy: 0.7124
# Epoch 4/20
# 24/24 [==============================] - 1s 57ms/step - loss: 0.6891 - accuracy: 0.7162 - val_loss: 0.6517 - val_accuracy: 0.7322
# Epoch 5/20
# 24/24 [==============================] - 1s 38ms/step - loss: 0.6262 - accuracy: 0.7511 - val_loss: 0.6059 - val_accuracy: 0.7595
# Epoch 6/20
# 24/24 [==============================] - 1s 37ms/step - loss: 0.5749 - accuracy: 0.7816 - val_loss: 0.5714 - val_accuracy: 0.7807
# Epoch 7/20
# 24/24 [==============================] - 1s 38ms/step - loss: 0.5318 - accuracy: 0.8098 - val_loss: 0.5452 - val_accuracy: 0.8012
# Epoch 8/20
# 24/24 [==============================] - 1s 36ms/step - loss: 0.4956 - accuracy: 0.8300 - val_loss: 0.5228 - val_accuracy: 0.8020
# Epoch 9/20
# 24/24 [==============================] - 1s 37ms/step - loss: 0.4648 - accuracy: 0.8417 - val_loss: 0.5055 - val_accuracy: 0.8058
# Epoch 10/20
# 24/24 [==============================] - 1s 38ms/step - loss: 0.4387 - accuracy: 0.8514 - val_loss: 0.4929 - val_accuracy: 0.8156
# Epoch 11/20
# 24/24 [==============================] - 1s 36ms/step - loss: 0.4162 - accuracy: 0.8587 - val_loss: 0.4842 - val_accuracy: 0.8171
# Epoch 12/20
# 24/24 [==============================] - 1s 37ms/step - loss: 0.3964 - accuracy: 0.8660 - val_loss: 0.4754 - val_accuracy: 0.8187
# Epoch 13/20
# 24/24 [==============================] - 1s 37ms/step - loss: 0.3788 - accuracy: 0.8711 - val_loss: 0.4706 - val_accuracy: 0.8179
# Epoch 14/20
# 24/24 [==============================] - 1s 38ms/step - loss: 0.3629 - accuracy: 0.8769 - val_loss: 0.4688 - val_accuracy: 0.8179
# Epoch 15/20
# 24/24 [==============================] - 1s 39ms/step - loss: 0.3485 - accuracy: 0.8824 - val_loss: 0.4663 - val_accuracy: 0.8179
# Epoch 16/20
# 24/24 [==============================] - 1s 55ms/step - loss: 0.3350 - accuracy: 0.8878 - val_loss: 0.4638 - val_accuracy: 0.8202
# Epoch 17/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.3226 - accuracy: 0.8911 - val_loss: 0.4638 - val_accuracy: 0.8202
# Epoch 18/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.3108 - accuracy: 0.8958 - val_loss: 0.4641 - val_accuracy: 0.8194
# Epoch 19/20
# 24/24 [==============================] - 1s 38ms/step - loss: 0.3001 - accuracy: 0.8995 - val_loss: 0.4659 - val_accuracy: 0.8171
# Epoch 20/20
# 24/24 [==============================] - 1s 39ms/step - loss: 0.2898 - accuracy: 0.9027 - val_loss: 0.4672 - val_accuracy: 0.8118
# Minimum validation loss reached in epoch 17

# %% [markdown]
# # Applying regularization
#
# You may be familiar with Occam's Razor principle: given two explanations for something, the explanation most likely to be correct is the "simplest" one, the one that makes the least amount of assumptions. This also applies to the models learned by neural networks: given some training data and a network architecture, there are multiple sets of weights values (multiple models) that could explain the data, and simpler models are less likely to overfit than complex ones.
#
# A "simple model" in this context is a model where the distribution of parameter values has less entropy (or a model with fewer parameters altogether, as we saw in the section above). Thus a common way to mitigate overfitting is to put constraints on the complexity of a network by forcing its weights only to take small values, which makes the distribution of weight values more "regular". This is called "weight regularization", and it is done by adding to the loss function of the network a cost associated with having large weights. This cost comes in two flavors:
#
# L1 regularization, where the cost added is proportional to the absolute value of the weights coefficients (i.e. to what is called the "L1 norm" of the weights).
#
# L2 regularization, where the cost added is proportional to the square of the value of the weights coefficients (i.e. to what is called the squared "L2 norm" of the weights). L2 regularization is also called weight decay in the context of neural networks. Don't let the different name confuse you: weight decay is mathematically the exact same as L2 regularization.
#
# L1 regularization pushes weights towards exactly zero encouraging a sparse model. L2 regularization will penalize the weights parameters without making them sparse since the penalty goes to zero for small weights-one reason why L2 is more common.
#
# In `tf.keras`, weight regularization is added by passing weight regularizer instances to layers as keyword arguments. Let's add L2 weight regularization now.

# %%
reg_model = models.Sequential()
reg_model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), activation='relu', input_shape=(NB_WORDS,)))
reg_model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), activation='relu'))
reg_model.add(layers.Dense(3, activation='softmax'))
reg_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 64)                640064
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  dense_7 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 644,419
# Trainable params: 644,419
# Non-trainable params: 0
# _________________________________________________________________

# %%
reg_history = deep_model(reg_model, X_train_rest, y_train_rest, X_valid, y_valid)
reg_min = optimal_epoch(reg_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 2s 76ms/step - loss: 1.0407 - accuracy: 0.6189 - val_loss: 0.8505 - val_accuracy: 0.6897
# Epoch 2/20
# 24/24 [==============================] - 1s 60ms/step - loss: 0.8014 - accuracy: 0.7180 - val_loss: 0.7099 - val_accuracy: 0.7815
# Epoch 3/20
# 24/24 [==============================] - 1s 58ms/step - loss: 0.6597 - accuracy: 0.8099 - val_loss: 0.6366 - val_accuracy: 0.8027
# Epoch 4/20
# 24/24 [==============================] - 1s 60ms/step - loss: 0.5617 - accuracy: 0.8457 - val_loss: 0.6101 - val_accuracy: 0.8141
# Epoch 5/20
# 24/24 [==============================] - 2s 63ms/step - loss: 0.4993 - accuracy: 0.8670 - val_loss: 0.5909 - val_accuracy: 0.8179
# Epoch 6/20
# 24/24 [==============================] - 2s 65ms/step - loss: 0.4542 - accuracy: 0.8828 - val_loss: 0.5899 - val_accuracy: 0.8111
# Epoch 7/20
# 24/24 [==============================] - 2s 102ms/step - loss: 0.4181 - accuracy: 0.8969 - val_loss: 0.6055 - val_accuracy: 0.8073
# Epoch 8/20
# 24/24 [==============================] - 2s 66ms/step - loss: 0.3896 - accuracy: 0.9062 - val_loss: 0.6275 - val_accuracy: 0.7936
# Epoch 9/20
# 24/24 [==============================] - 1s 60ms/step - loss: 0.3651 - accuracy: 0.9156 - val_loss: 0.6174 - val_accuracy: 0.8088
# Epoch 10/20
# 24/24 [==============================] - 1s 61ms/step - loss: 0.3455 - accuracy: 0.9229 - val_loss: 0.6316 - val_accuracy: 0.7967
# Epoch 11/20
# 24/24 [==============================] - 1s 60ms/step - loss: 0.3271 - accuracy: 0.9297 - val_loss: 0.6437 - val_accuracy: 0.8020
# Epoch 12/20
# 24/24 [==============================] - 1s 61ms/step - loss: 0.3127 - accuracy: 0.9341 - val_loss: 0.6527 - val_accuracy: 0.7944
# Epoch 13/20
# 24/24 [==============================] - 1s 60ms/step - loss: 0.2993 - accuracy: 0.9413 - val_loss: 0.6809 - val_accuracy: 0.7807
# Epoch 14/20
# 24/24 [==============================] - 1s 61ms/step - loss: 0.2874 - accuracy: 0.9448 - val_loss: 0.6815 - val_accuracy: 0.7921
# Epoch 15/20
# 24/24 [==============================] - 4s 166ms/step - loss: 0.2759 - accuracy: 0.9496 - val_loss: 0.6841 - val_accuracy: 0.7967
# Epoch 16/20
# 24/24 [==============================] - 2s 93ms/step - loss: 0.2672 - accuracy: 0.9515 - val_loss: 0.6986 - val_accuracy: 0.7838
# Epoch 17/20
# 24/24 [==============================] - 1s 61ms/step - loss: 0.2578 - accuracy: 0.9561 - val_loss: 0.7383 - val_accuracy: 0.7785
# Epoch 18/20
# 24/24 [==============================] - 1s 61ms/step - loss: 0.2515 - accuracy: 0.9578 - val_loss: 0.7055 - val_accuracy: 0.7921
# Epoch 19/20
# 24/24 [==============================] - 2s 63ms/step - loss: 0.2420 - accuracy: 0.9620 - val_loss: 0.7181 - val_accuracy: 0.7868
# Epoch 20/20
# 24/24 [==============================] - 1s 61ms/step - loss: 0.2351 - accuracy: 0.9628 - val_loss: 0.7172 - val_accuracy: 0.7883
# Minimum validation loss reached in epoch 6

# %% [markdown]
# For the regularized model we notice that it starts overfitting in the same epoch as the baseline model. However, the loss increases much slower afterwards.

# %%
eval_metric(reg_model, reg_history, 'loss')

# %%
compare_models_by_metric(base_model, reg_model, base_history, reg_history, 'val_loss')

# %% [markdown]
# ## Question 1
#
# First identify (provide the name of) and then code the regularizer which is used in the following loss function:
#
# $$cost = (\mathbf{y} - \mathbf{x}W)^2 + λ||W||$$
#
# Let's assume $w = [-5, 4, -3, 2, 1]$

# %% [markdown]
# ###  Answer 1

# %%
weights = [-5, 4, -3, 2, 1]
#The name of the loss funtion is L1 regularization
def l1_norm(weights):
    # Enter your code here
    reg = sum(abs(weight) for weight in weights)
    return reg

print(l1_norm(weights))
# Out:
# 15

# %% [markdown]
# ## Question 2
#
# First identify (provide the name of) and then code the regularizer which is used in the following loss function:
#
# $$cost = (\mathbf{y} - \mathbf{x}W)^2 + λ||W||_2^2$$
#
# Let's assume $w = [-5, 4, -3, 2, 1]$

# %% [markdown]
# ###  Answer 2

# %%
weights = [-5, 4, -3, 2, 1]

#The name of the loss funtion is L2 regularization
def l2_norm(weights):
    # Enter your code here
    reg = sum(weight**2 for weight in weights)
    return reg

print(l2_norm(weights))
# Out:
# 55

# %% [markdown]
# ## Adding dropout layers
# Add dropout
# Dropout is one of the most effective and most commonly used regularization techniques for neural networks, developed by Hinton and his students at the University of Toronto.
#
# The intuitive explanation for dropout is that because individual nodes in the network cannot rely on the output of the others, each node must output features that are useful on their own.
#
# Dropout, applied to a layer, consists of randomly "dropping out" (i.e. set to zero) a number of output features of the layer during training. Let's say a given layer would normally have returned a vector [0.2, 0.5, 1.3, 0.8, 1.1] for a given input sample during training; after applying dropout, this vector will have a few zero entries distributed at random, e.g. [0, 0.5, 1.3, 0, 1.1].
#
# The "dropout rate" is the fraction of the features that are being zeroed-out; it is usually set between 0.2 and 0.5. At test time, no units are dropped out, and instead the layer's output values are scaled down by a factor equal to the dropout rate, so as to balance for the fact that more units are active than at training time.
#
# In `tf.keras` you can introduce dropout in a network via the Dropout layer, which gets applied to the output of layer right before.
#
# Let's add two Dropout layers in our network to see how well they do at reducing overfitting:

# %%
drop_model = models.Sequential()
drop_model.add(layers.Dense(64, activation='relu', input_shape=(NB_WORDS,)))
drop_model.add(layers.Dropout(0.5))
drop_model.add(layers.Dense(64, activation='relu'))
drop_model.add(layers.Dropout(0.5))
drop_model.add(layers.Dense(3, activation='softmax'))
drop_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 64)                640064
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_9 (Dense)             (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_10 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 644,419
# Trainable params: 644,419
# Non-trainable params: 0
# _________________________________________________________________

# %%
drop_history = deep_model(drop_model, X_train_rest, y_train_rest, X_valid, y_valid)
drop_min = optimal_epoch(drop_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 3s 112ms/step - loss: 0.9392 - accuracy: 0.5976 - val_loss: 0.7544 - val_accuracy: 0.6495
# Epoch 2/20
# 24/24 [==============================] - 2s 75ms/step - loss: 0.7647 - accuracy: 0.6316 - val_loss: 0.6618 - val_accuracy: 0.6859
# Epoch 3/20
# 24/24 [==============================] - 1s 60ms/step - loss: 0.6696 - accuracy: 0.7066 - val_loss: 0.5880 - val_accuracy: 0.7747
# Epoch 4/20
# 24/24 [==============================] - 1s 61ms/step - loss: 0.5867 - accuracy: 0.7785 - val_loss: 0.5364 - val_accuracy: 0.8073
# Epoch 5/20
# 24/24 [==============================] - 2s 63ms/step - loss: 0.5255 - accuracy: 0.8151 - val_loss: 0.5024 - val_accuracy: 0.8126
# Epoch 6/20
# 24/24 [==============================] - 1s 61ms/step - loss: 0.4624 - accuracy: 0.8337 - val_loss: 0.4822 - val_accuracy: 0.8118
# Epoch 7/20
# 24/24 [==============================] - 1s 61ms/step - loss: 0.4228 - accuracy: 0.8526 - val_loss: 0.4781 - val_accuracy: 0.8103
# Epoch 8/20
# 24/24 [==============================] - 1s 59ms/step - loss: 0.3885 - accuracy: 0.8611 - val_loss: 0.4777 - val_accuracy: 0.8156
# Epoch 9/20
# 24/24 [==============================] - 2s 95ms/step - loss: 0.3586 - accuracy: 0.8776 - val_loss: 0.4833 - val_accuracy: 0.8149
# Epoch 10/20
# 24/24 [==============================] - 2s 84ms/step - loss: 0.3288 - accuracy: 0.8884 - val_loss: 0.4881 - val_accuracy: 0.8171
# Epoch 11/20
# 24/24 [==============================] - 2s 63ms/step - loss: 0.3036 - accuracy: 0.8930 - val_loss: 0.4976 - val_accuracy: 0.8134
# Epoch 12/20
# 24/24 [==============================] - 1s 62ms/step - loss: 0.2783 - accuracy: 0.9072 - val_loss: 0.5129 - val_accuracy: 0.8088
# Epoch 13/20
# 24/24 [==============================] - 2s 63ms/step - loss: 0.2676 - accuracy: 0.9102 - val_loss: 0.5222 - val_accuracy: 0.8073
# Epoch 14/20
# 24/24 [==============================] - 1s 62ms/step - loss: 0.2424 - accuracy: 0.9202 - val_loss: 0.5373 - val_accuracy: 0.8005
# Epoch 15/20
# 24/24 [==============================] - 2s 65ms/step - loss: 0.2253 - accuracy: 0.9231 - val_loss: 0.5618 - val_accuracy: 0.8126
# Epoch 16/20
# 24/24 [==============================] - 1s 61ms/step - loss: 0.2151 - accuracy: 0.9287 - val_loss: 0.5768 - val_accuracy: 0.8005
# Epoch 17/20
# 24/24 [==============================] - 2s 98ms/step - loss: 0.1997 - accuracy: 0.9319 - val_loss: 0.5917 - val_accuracy: 0.8103
# Epoch 18/20
# 24/24 [==============================] - 2s 77ms/step - loss: 0.1858 - accuracy: 0.9382 - val_loss: 0.6068 - val_accuracy: 0.8050
# Epoch 19/20
# 24/24 [==============================] - 1s 60ms/step - loss: 0.1682 - accuracy: 0.9442 - val_loss: 0.6286 - val_accuracy: 0.8073
# Epoch 20/20
# 24/24 [==============================] - 1s 60ms/step - loss: 0.1613 - accuracy: 0.9478 - val_loss: 0.6509 - val_accuracy: 0.8042
# Minimum validation loss reached in epoch 8

# %%
eval_metric(drop_model, drop_history, 'loss')

# %% [markdown]
# The model with dropout layers starts overfitting later than the baseline model. The loss also increases slower than the baseline model.

# %%
compare_models_by_metric(base_model, drop_model, base_history, drop_history, 'val_loss')

# %% [markdown]
# The model with the Dropout layers starts overfitting later. Compared to the baseline model the loss also remains much lower.

# %% [markdown]
# ## Combined L2 + dropout

# %%
combined_model = tf.keras.Sequential([
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu', input_shape=(NB_WORDS,)),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(3)
])

# %%
combined_history = deep_model(combined_model, X_train_rest, y_train_rest, X_valid, y_valid)
combined_min = optimal_epoch(combined_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 11s 421ms/step - loss: nan - accuracy: 0.6041 - val_loss: nan - val_accuracy: 0.6495
# Epoch 2/20
# 24/24 [==============================] - 9s 369ms/step - loss: nan - accuracy: 0.6224 - val_loss: nan - val_accuracy: 0.6495
# Epoch 3/20
# 24/24 [==============================] - 8s 336ms/step - loss: nan - accuracy: 0.6224 - val_loss: nan - val_accuracy: 0.6495
# Epoch 4/20
# 24/24 [==============================] - 9s 392ms/step - loss: nan - accuracy: 0.6224 - val_loss: nan - val_accuracy: 0.6495
# Epoch 5/20
# 24/24 [==============================] - 9s 381ms/step - loss: nan - accuracy: 0.6224 - val_loss: nan - val_accuracy: 0.6495
# Epoch 6/20
# 24/24 [==============================] - 8s 332ms/step - loss: nan - accuracy: 0.6224 - val_loss: nan - val_accuracy: 0.6495
# Epoch 7/20
# 24/24 [==============================] - 9s 388ms/step - loss: nan - accuracy: 0.6224 - val_loss: nan - val_accuracy: 0.6495
# Epoch 8/20
# 24/24 [==============================] - 9s 388ms/step - loss: nan - accuracy: 0.6224 - val_loss: nan - val_accuracy: 0.6495
# Epoch 9/20
# 24/24 [==============================] - 8s 329ms/step - loss: nan - accuracy: 0.6224 - val_loss: nan - val_accuracy: 0.6495
# Epoch 10/20
# 24/24 [==============================] - 9s 380ms/step - loss: nan - accuracy: 0.6224 - val_loss: nan - val_accuracy: 0.6495
# Epoch 11/20
# 24/24 [==============================] - 9s 384ms/step - loss: nan - accuracy: 0.6224 - val_loss: nan - val_accuracy: 0.6495
# Epoch 12/20
# 24/24 [==============================] - 8s 343ms/step - loss: nan - accuracy: 0.6224 - val_loss: nan - val_accuracy: 0.6495
# Epoch 13/20
# 24/24 [==============================] - 9s 381ms/step - loss: nan - accuracy: 0.6224 - val_loss: nan - val_accuracy: 0.6495
# Epoch 14/20
# 24/24 [==============================] - 9s 395ms/step - loss: nan - accuracy: 0.6224 - val_loss: nan - val_accuracy: 0.6495
# Epoch 15/20
# 24/24 [==============================] - 9s 381ms/step - loss: nan - accuracy: 0.6224 - val_loss: nan - val_accuracy: 0.6495
# Epoch 16/20
# 24/24 [==============================] - 9s 387ms/step - loss: nan - accuracy: 0.6224 - val_loss: nan - val_accuracy: 0.6495
# Epoch 17/20
# 24/24 [==============================] - 12s 517ms/step - loss: nan - accuracy: 0.6224 - val_loss: nan - val_accuracy: 0.6495
# Epoch 18/20
# 24/24 [==============================] - 11s 462ms/step - loss: nan - accuracy: 0.6224 - val_loss: nan - val_accuracy: 0.6495
# Epoch 19/20
# 24/24 [==============================] - 8s 347ms/step - loss: nan - accuracy: 0.6224 - val_loss: nan - val_accuracy: 0.6495
# Epoch 20/20
# 24/24 [==============================] - 9s 382ms/step - loss: nan - accuracy: 0.6224 - val_loss: nan - val_accuracy: 0.6495
# Minimum validation loss reached in epoch 1

# %%
eval_metric(combined_model, combined_history, 'loss')

# %%
compare_models_by_metric(base_model, combined_model, base_history, combined_history, 'val_loss')

# %% [markdown]
# ## Question 3
#
# When does it make sense to add both L2 regularization and Dropout?
#
# And what did doing so achieve in this case?

# %% [markdown]
# ### Answer 3
#
# \<*It makes sense to add both L2 regularization and Dropout when working with complex machine learning models like neural networks, what they do is prevent overfitting. L2 helps prevent overfitting by penalizing larger weights and dropout is used to handle unnecesary features, it sets random neurons to 0 over the forward pass, preventing complex co-adaptations between neurons and encourages to learn more difficult representations when working with big neural networks. This helps to prevent overfitting. *\>

# %% [markdown]
# #Training on the full train data and evaluation on test data
# At first sight the reduced model seems to be the best model for generalization. But let's check that on the test set.

# %%
base_results = test_model(base_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, base_min)
# Out:
# Epoch 1/5
# 26/26 [==============================] - 4s 144ms/step - loss: 0.1365 - accuracy: 0.9633
# Epoch 2/5
# 26/26 [==============================] - 3s 102ms/step - loss: 0.0936 - accuracy: 0.9717
# Epoch 3/5
# 26/26 [==============================] - 3s 96ms/step - loss: 0.0747 - accuracy: 0.9771
# Epoch 4/5
# 26/26 [==============================] - 3s 109ms/step - loss: 0.0619 - accuracy: 0.9818
# Epoch 5/5
# 26/26 [==============================] - 3s 132ms/step - loss: 0.0525 - accuracy: 0.9848
# 46/46 [==============================] - 1s 11ms/step - loss: 0.9622 - accuracy: 0.7821
#
# Test accuracy: 78.21%

# %%
reduced_results = test_model(reduced_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, reduced_min)
# Out:
# Epoch 1/17
# 26/26 [==============================] - 2s 63ms/step - loss: 0.2990 - accuracy: 0.8959
# Epoch 2/17
# 26/26 [==============================] - 1s 37ms/step - loss: 0.2883 - accuracy: 0.9005
# Epoch 3/17
# 26/26 [==============================] - 1s 35ms/step - loss: 0.2784 - accuracy: 0.9032
# Epoch 4/17
# 26/26 [==============================] - 1s 35ms/step - loss: 0.2692 - accuracy: 0.9079
# Epoch 5/17
# 26/26 [==============================] - 1s 34ms/step - loss: 0.2605 - accuracy: 0.9109
# Epoch 6/17
# 26/26 [==============================] - 1s 35ms/step - loss: 0.2524 - accuracy: 0.9143
# Epoch 7/17
# 26/26 [==============================] - 1s 36ms/step - loss: 0.2444 - accuracy: 0.9183
# Epoch 8/17
# 26/26 [==============================] - 1s 35ms/step - loss: 0.2371 - accuracy: 0.9214
# Epoch 9/17
# 26/26 [==============================] - 1s 36ms/step - loss: 0.2301 - accuracy: 0.9225
# Epoch 10/17
# 26/26 [==============================] - 1s 53ms/step - loss: 0.2232 - accuracy: 0.9261
# Epoch 11/17
# 26/26 [==============================] - 1s 52ms/step - loss: 0.2168 - accuracy: 0.9281
# Epoch 12/17
# 26/26 [==============================] - 1s 40ms/step - loss: 0.2106 - accuracy: 0.9303
# Epoch 13/17
# 26/26 [==============================] - 1s 35ms/step - loss: 0.2049 - accuracy: 0.9333
# Epoch 14/17
# 26/26 [==============================] - 1s 34ms/step - loss: 0.1993 - accuracy: 0.9356
# Epoch 15/17
# 26/26 [==============================] - 1s 35ms/step - loss: 0.1938 - accuracy: 0.9386
# Epoch 16/17
# 26/26 [==============================] - 1s 35ms/step - loss: 0.1886 - accuracy: 0.9394
# Epoch 17/17
# 26/26 [==============================] - 1s 34ms/step - loss: 0.1834 - accuracy: 0.9414
# 46/46 [==============================] - 0s 3ms/step - loss: 0.5746 - accuracy: 0.7944
#
# Test accuracy: 79.44%

# %%
reg_results = test_model(reg_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, reg_min)
# Out:
# Epoch 1/6
# 26/26 [==============================] - 4s 163ms/step - loss: 0.2816 - accuracy: 0.9458
# Epoch 2/6
# 26/26 [==============================] - 2s 73ms/step - loss: 0.2527 - accuracy: 0.9555
# Epoch 3/6
# 26/26 [==============================] - 2s 59ms/step - loss: 0.2410 - accuracy: 0.9590
# Epoch 4/6
# 26/26 [==============================] - 2s 58ms/step - loss: 0.2302 - accuracy: 0.9630
# Epoch 5/6
# 26/26 [==============================] - 1s 56ms/step - loss: 0.2213 - accuracy: 0.9667
# Epoch 6/6
# 26/26 [==============================] - 1s 56ms/step - loss: 0.2176 - accuracy: 0.9671
# 46/46 [==============================] - 0s 5ms/step - loss: 0.7562 - accuracy: 0.7910
#
# Test accuracy: 79.10%

# %%
drop_results = test_model(drop_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, drop_min)
# Out:
# Epoch 1/8
# 26/26 [==============================] - 2s 62ms/step - loss: 0.2048 - accuracy: 0.9350
# Epoch 2/8
# 26/26 [==============================] - 2s 58ms/step - loss: 0.1866 - accuracy: 0.9405
# Epoch 3/8
# 26/26 [==============================] - 1s 56ms/step - loss: 0.1747 - accuracy: 0.9462
# Epoch 4/8
# 26/26 [==============================] - 2s 93ms/step - loss: 0.1589 - accuracy: 0.9490
# Epoch 5/8
# 26/26 [==============================] - 2s 70ms/step - loss: 0.1497 - accuracy: 0.9526
# Epoch 6/8
# 26/26 [==============================] - 2s 58ms/step - loss: 0.1391 - accuracy: 0.9559
# Epoch 7/8
# 26/26 [==============================] - 1s 57ms/step - loss: 0.1313 - accuracy: 0.9581
# Epoch 8/8
# 26/26 [==============================] - 1s 57ms/step - loss: 0.1196 - accuracy: 0.9621
# 46/46 [==============================] - 0s 4ms/step - loss: 0.7779 - accuracy: 0.7903
#
# Test accuracy: 79.03%

# %% [markdown]
# # Handling Underfitting
# * In a general situation, the best strategy is to increase the model complexity by either increasing the number of parameters of your deep learning model or the order of your model. Underfitting is due to the model being simpler than needed. It fails to capture the patterns in the data. Increasing the model complexity will lead to improvement in training performance. If we use a large enough model it can even achieve a training error of zero i.e. the model will memorize the data and suffer from over-fitting. The goal is to hit the optimal sweet spot.
# * Try to train the model for more epochs. Ensure that the loss is decreasing gradually over the course of the training. Otherwise, it is highly likely that there is some kind of bug or problem in the training code/logic itself.
# * If you aren’t shuffling the data after every epoch, it can harm the model performance. Ensuring that you are shuffling the data is a good check to perform at this point.

# %% [markdown]
# #Conclusion
# To recap: here are the most common ways to prevent overfitting in neural networks:
#
# * Get more training data.
# * Reduce the capacity of the network.
# * Add weight regularization.
# * Add dropout.
#
# Two important approaches not covered in this guide are:
#
# * data-augmentation
# * batch normalization
#
# Remember that each method can help on its own, but often combining them can be even more effective.
#
# here are the ways to prevent underfitting
#
# * Get more training data.
# * Increase the size or number of parameters in the model.
# * Increase the complexity of the model.
# * Increasing the training time, until cost function is minimised.

# %% [markdown]
# # Bonus content - Visualizing L2 regularization

# %%
import numpy as np
#%matplotlib notebook
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.core.debugger import set_trace
import warnings
warnings.filterwarnings('ignore')
import itertools

# %%
def plot_contour(f, x1bound, x2bound, resolution, ax):
    x1range = np.linspace(x1bound[0], x1bound[1], resolution)
    x2range = np.linspace(x2bound[0], x2bound[1], resolution)
    xg, yg = np.meshgrid(x1range, x2range)
    zg = np.zeros_like(xg)
    for i,j in itertools.product(range(resolution), range(resolution)):
        zg[i,j] = f([xg[i,j], yg[i,j]])
    ax.contour(xg, yg, zg, 100)
    return ax

# %% [markdown]
# Let's create a toy data:

# %%
N = 20
x = np.random.rand(N) * 10
y = -4*x + 10 + 2*np.random.randn(N)

# %% [markdown]
# visualize the regularized **cost function**

# %%
cost = lambda w: .5*np.mean((w[0] + w[1]*x - y)**2)
l2_penalty = lambda w: np.dot(w,w)/2
cost_plus_l2 = lambda w: cost(w) + 5*l2_penalty(w)

fig, axes = plt.subplots(ncols=3, nrows=1, constrained_layout=True, figsize=(15, 5))
plot_contour(cost, [-20,20], [-20,20], 50, axes[0])
axes[0].set_title(r'cost function $J(w)$')
plot_contour(l2_penalty, [-20,20], [-20,20], 50, axes[1])
axes[1].set_title(r'L2 reg. $||w||_2^2$')
plot_contour(cost_plus_l2, [-20,20], [-20,20], 50, axes[2])
axes[2].set_title(r'L2 reg. cost $J(w) + 5 ||w||_2^2$')
plt.show()

# %% [markdown]
# ## Bonus Question 1
#
# Plot the same for L1 regularization

# %% [markdown]
# ### Answer

# %%
cost = #Enter your code here
l1_penalty = #Enter your code here
cost_plus_l2 = #Enter your code here

fig, axes = plt.subplots(ncols=3, nrows=1, constrained_layout=True, figsize=(15, 5))
plot_contour(cost, [-20,20], [-20,20], 50, axes[0])
axes[0].set_title(r'cost function $J(w)$')
plot_contour(l1_penalty, [-20,20], [-20,20], 50, axes[1])
axes[1].set_title(r'L1 reg. $||w||_2^2$')
plot_contour(cost_plus_l1, [-20,20], [-20,20], 50, axes[2])
axes[2].set_title(r'L1 reg. cost $J(w) + 5 ||w||_2^2$')
plt.show()

# %% [markdown]
# ## Bonus Question 2
# After looking at the visualization to what the L1 and L2 normalizations, how do they help while training?
#
# \<*Type your answer here*\>

# %% [markdown]
# # Upload this Colab Notebook to your Github repository. Also add your *reflections* on today's learning in README.md
